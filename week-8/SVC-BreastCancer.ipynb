# %%
#SVC - Support Vector Classifier on Breast Cancer Wisconsin Dataset

# Importing necessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, classification_report,confusion_matrix

# %%
# Load the dataset
dp = pd.read_csv("wdbc.data", header=None)
print(dp.head())
# Out:
#          0  1      2      3       4       5        6        7       8   \
# 0    842302  M  17.99  10.38  122.80  1001.0  0.11840  0.27760  0.3001
# 1    842517  M  20.57  17.77  132.90  1326.0  0.08474  0.07864  0.0869
# 2  84300903  M  19.69  21.25  130.00  1203.0  0.10960  0.15990  0.1974
# 3  84348301  M  11.42  20.38   77.58   386.1  0.14250  0.28390  0.2414
# 4  84358402  M  20.29  14.34  135.10  1297.0  0.10030  0.13280  0.1980
#
#         9   ...     22     23      24      25      26      27      28      29  \
# 0  0.14710  ...  25.38  17.33  184.60  2019.0  0.1622  0.6656  0.7119  0.2654
# 1  0.07017  ...  24.99  23.41  158.80  1956.0  0.1238  0.1866  0.2416  0.1860
# 2  0.12790  ...  23.57  25.53  152.50  1709.0  0.1444  0.4245  0.4504  0.2430
# 3  0.10520  ...  14.91  26.50   98.87   567.7  0.2098  0.8663  0.6869  0.2575
# 4  0.10430  ...  22.54  16.67  152.20  1575.0  0.1374  0.2050  0.4000  0.1625
#
#        30       31
# 0  0.4601  0.11890
# 1  0.2750  0.08902
# ...

# %%
# Separate features and target variable
x= dp.iloc[:, 2:]   #columns from index 2 to the end
y = dp.iloc[:, 1]    # index 1 (the diagnosis)
print(X.shape) 
print(y.shape)
# Out:
# (569, 30)
# (569,)

# %%
# Split the dataset into training and testing sets
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=42)

# %%
# Train the SVM model
svm_model=SVC(
    kernel='rbf',   #kernal basis function
    C=1.0,          #regularization parameter
    gamma='scale'   #kernal coeff
)
svm_model.fit(x_train,y_train)
# Out:
# SVC()

# %%
# train the model and evaluate the model
y_pred=svm_model.predict(x_test)
print("accuracy:", accuracy_score(y_pred,y_test))
print("confusion matrix:",confusion_matrix(y_pred, y_test))
print("classification report:",classification_report(y_pred,y_test))
# Out:
# accuracy: 0.935672514619883
# confusion matrix: [[108  11]
#  [  0  52]]
# classification report:               precision    recall  f1-score   support
#
#            B       1.00      0.91      0.95       119
#            M       0.83      1.00      0.90        52
#
#     accuracy                           0.94       171
#    macro avg       0.91      0.95      0.93       171
# weighted avg       0.95      0.94      0.94       171
